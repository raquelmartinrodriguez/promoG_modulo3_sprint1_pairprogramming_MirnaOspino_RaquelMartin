# %% [markdown]
# ## Ejercicios apply

# %% [markdown]
# 1. Las columnas land_area, armed_forces_size, co2-emissions, gdp, population, urban_population, latitude, longitude, density, cpi son de tipo object pero en realidad deberían ser numéricas. Crea una función que nos permita cambiar el tipo de dato de estas columnas al que le corresponde.

# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np


# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
# cargamos el dataframe creado en la lección anterior
df = pd.read_csv("world_data_total.csv", index_col = 0)
df.head(6)
# Out:
#             density(p/km2) abbreviation  agricultural_land  land_area  \
# unnamed_0_x
# 0                       60           AF               58.1    652,230
# 1                      105           AL               43.1     28,748
# 2                       18           DZ               17.4  2,381,741
# 3                      164           AD               40.0        468
# 4                       26           AO               47.5  1,246,700
# 5                      223           AG               20.5        443
#
#             armed_forces_size  birth_rate  calling_code  \
# unnamed_0_x
# 0                     323,000       32.49          93.0
# 1                       9,000       11.78         355.0
# 2                     317,000       24.28         213.0
# 3                         NaN        7.20         376.0
# 4                     117,000       40.73         244.0
# 5                           0       15.33           1.0
#
#                  capital/major_city co2-emissions     cpi  cpi_change  \
# unnamed_0_x
# 0                             Kabul         8,672   149.9         2.3
# 1                            Tirana         4,536  119.05         1.4
# 2                           Algiers       150,006  151.36         2.0
# 3                  Andorra la Vella           469     NaN         NaN
# 4                            Luanda        34,693  261.73        17.1
# 5            St. John's, Saint John           557  113.81         1.2
#
#             currency-code  fertility_rate  forested_area  gasoline_price  \
# unnamed_0_x
# 0                     AFN            4.47            2.1            0.70
# 1                     ALL            1.62           28.1            1.36
# 2                     DZD            3.02            0.8            0.28
# 3                     EUR            1.27           34.0            1.51
# 4                     AOA            5.52           46.3            0.97
# 5                     XCD            1.99           22.3            0.99
#
#              unnamed_0_y               gdp  \
# unnamed_0_x
# 0                      0   19,101,353,833
# 1                      1   15,278,077,447
# 2                      2  169,988,236,398
# 3                      3    3,154,057,987
# 4                      4   94,635,415,870
# 5                      5    1,727,759,259
#
#              gross_primary_education_enrollment  \
# unnamed_0_x
# 0                                         104.0
# 1                                         107.0
# 2                                         109.9
# 3                                         106.4
# 4                                         113.5
# 5                                         105.0
#
#              gross_tertiary_education_enrollment  infant_mortality  \
# unnamed_0_x
# 0                                            9.7              47.9
# 1                                           55.0               7.8
# 2                                           51.4              20.1
# 3                                            NaN               2.7
# 4                                            9.3              51.6
# 5                                           24.8               5.0
#
#                        largest_city  life_expectancy  \
# unnamed_0_x
# 0                             Kabul             64.5
# 1                            Tirana             78.5
# 2                           Algiers             76.7
# 3                  Andorra la Vella              NaN
# 4                            Luanda             60.8
# 5            St. John's, Saint John             76.9
#
#              maternal_mortality_ratio  minimum_wage official_language  \
# unnamed_0_x
# 0                               638.0          0.43            Pashto
# 1                                15.0          1.12          Albanian
# 2                               112.0          0.95            Arabic
# 3                                 NaN          6.63           Catalan
# 4                               241.0          0.71        Portuguese
# 5                                42.0          3.04           English
#
#              out_of_pocket_health_expenditure  physicians_per_thousand  \
# unnamed_0_x
# 0                                        78.4                     0.28
# 1                                        56.9                     1.20
# 2                                        28.1                     1.72
# 3                                        36.4                     3.33
# 4                                        33.4                     0.21
# 5                                        24.3                     2.76
#
#              population  population_labor_force_participation  tax_revenue  \
# unnamed_0_x
# 0            38,041,754                                  48.9          9.3
# 1             2,854,191                                  55.7         18.6
# 2            43,053,054                                  41.2         37.2
# 3                77,142                                   NaN          NaN
# 4            31,825,295                                  77.5          9.2
# 5                97,118                                   NaN         16.5
#
#              total_tax_rate  unemployment_rate urban_population  \
# unnamed_0_x
# 0                      71.4              11.12        9,797,273
# 1                      36.6              12.33        1,747,593
# 2                      66.1              11.70       31,510,100
# 3                       NaN                NaN           67,873
# 4                      49.1               6.89       21,061,025
# 5                      43.0                NaN           23,800
#
#                          country         latitud        longitud
# unnamed_0_x
# 0                    Afghanistan    ('33.93911 '    '67.709953')
# 1                        Albania   ('41.153332 '    '20.168331')
# 2                        Algeria   ('28.033886 '     '1.659626')
# 3                        Andorra   ('42.506285 '     '1.521801')
# 4                         Angola  ('-11.202692 '    '17.873887')
# 5            Antigua and Barbuda   ('17.060816 '   '-61.796428')

# %%
df [['land_area', 'armed_forces_size', 'co2-emissions', 'gdp', 'population', 'urban_population', 'latitud', 'longitud', 'density(p/km2)', 'cpi']]
# Out:
#              land_area armed_forces_size co2-emissions               gdp  \
# unnamed_0_x
# 0              652,230           323,000         8,672   19,101,353,833
# 1               28,748             9,000         4,536   15,278,077,447
# 2            2,381,741           317,000       150,006  169,988,236,398
# 3                  468               NaN           469    3,154,057,987
# 4            1,246,700           117,000        34,693   94,635,415,870
# ...                ...               ...           ...               ...
# 190            912,050           343,000       164,175  482,359,318,768
# 191            331,210           522,000       192,668  261,921,244,843
# 192            527,968            40,000        10,609   26,914,402,224
# 193            752,618            16,000         5,141   23,064,722,446
# 194            390,757            51,000        10,983   21,440,758,800
#
#              population urban_population         latitud        longitud  \
# unnamed_0_x
# 0            38,041,754        9,797,273    ('33.93911 '    '67.709953')
# 1             2,854,191        1,747,593   ('41.153332 '    '20.168331')
# 2            43,053,054       31,510,100   ('28.033886 '     '1.659626')
# 3                77,142           67,873   ('42.506285 '     '1.521801')
# 4            31,825,295       21,061,025  ('-11.202692 '    '17.873887')
# ...                 ...              ...             ...             ...
# 190          28,515,829       25,162,368     ('6.42375 '    '-66.58973')
# 191          96,462,106       35,332,140   ('14.058324 '   '108.277199')
# 192          29,161,922       10,869,523   ('15.552727 '    '48.516388')
# 193          17,861,030        7,871,713  ('-13.133897 '    '27.849332')
# 194          14,645,468        4,717,305  ('-19.015438 '    '29.154857')
#
#             density(p/km2)       cpi
# unnamed_0_x
# 0                       60     149.9
# 1                      105    119.05
# 2                       18    151.36
# 3                      164       NaN
# 4                       26    261.73
# ...                    ...       ...
# 190                     32  2,740.27
# 191                    314    163.52
# 192                     56    157.58
# 193                     25    212.31
# 194                     38    105.51
#
# [195 rows x 10 columns]

# %%
numero = '652,230'

# %%
def cambiar_tipo (num):
    try:
        nuevo_tipo = float(num.replace (',', ''))
        return nuevo_tipo

    except: 
        return np.nan

# %%
cambiar_tipo (numero)
# Out:
# 652230.0

# %%
df ['land_area'] = df ['land_area'].apply (cambiar_tipo)

# %%
columnas = ['land_area', 'armed_forces_size', 'co2-emissions', 'gdp', 'population', 'urban_population', 'latitud', 'longitud', 'density(p/km2)', 'cpi']

# %%
for columna in columnas:
    df [columna] = df [columna].apply (cambiar_tipo)

# %%
df.head()
# Out:
#              density(p/km2) abbreviation  agricultural_land  land_area  \
# unnamed_0_x
# 0                      60.0           AF               58.1   652230.0
# 1                     105.0           AL               43.1    28748.0
# 2                      18.0           DZ               17.4  2381741.0
# 3                     164.0           AD               40.0      468.0
# 4                      26.0           AO               47.5  1246700.0
#
#              armed_forces_size  birth_rate  calling_code capital/major_city  \
# unnamed_0_x
# 0                     323000.0       32.49          93.0              Kabul
# 1                       9000.0       11.78         355.0             Tirana
# 2                     317000.0       24.28         213.0            Algiers
# 3                          NaN        7.20         376.0   Andorra la Vella
# 4                     117000.0       40.73         244.0             Luanda
#
#              co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# unnamed_0_x
# 0                   8672.0  149.90         2.3           AFN            4.47
# 1                   4536.0  119.05         1.4           ALL            1.62
# 2                 150006.0  151.36         2.0           DZD            3.02
# 3                    469.0     NaN         NaN           EUR            1.27
# 4                  34693.0  261.73        17.1           AOA            5.52
#
#              forested_area  gasoline_price  unnamed_0_y           gdp  \
# unnamed_0_x
# 0                      2.1            0.70            0  1.910135e+10
# 1                     28.1            1.36            1  1.527808e+10
# 2                      0.8            0.28            2  1.699882e+11
# 3                     34.0            1.51            3  3.154058e+09
# 4                     46.3            0.97            4  9.463542e+10
#
#              gross_primary_education_enrollment  \
# unnamed_0_x
# 0                                         104.0
# 1                                         107.0
# 2                                         109.9
# 3                                         106.4
# 4                                         113.5
#
#              gross_tertiary_education_enrollment  infant_mortality  \
# unnamed_0_x
# 0                                            9.7              47.9
# 1                                           55.0               7.8
# 2                                           51.4              20.1
# 3                                            NaN               2.7
# 4                                            9.3              51.6
#
#                  largest_city  life_expectancy  maternal_mortality_ratio  \
# unnamed_0_x
# 0                       Kabul             64.5                     638.0
# 1                      Tirana             78.5                      15.0
# 2                     Algiers             76.7                     112.0
# 3            Andorra la Vella              NaN                       NaN
# 4                      Luanda             60.8                     241.0
#
#              minimum_wage official_language  out_of_pocket_health_expenditure  \
# unnamed_0_x
# 0                    0.43            Pashto                              78.4
# 1                    1.12          Albanian                              56.9
# 2                    0.95            Arabic                              28.1
# 3                    6.63           Catalan                              36.4
# 4                    0.71        Portuguese                              33.4
#
#              physicians_per_thousand  population  \
# unnamed_0_x
# 0                               0.28  38041754.0
# 1                               1.20   2854191.0
# 2                               1.72  43053054.0
# 3                               3.33     77142.0
# 4                               0.21  31825295.0
#
#              population_labor_force_participation  tax_revenue  \
# unnamed_0_x
# 0                                            48.9          9.3
# 1                                            55.7         18.6
# 2                                            41.2         37.2
# 3                                             NaN          NaN
# 4                                            77.5          9.2
#
#              total_tax_rate  unemployment_rate  urban_population      country  \
# unnamed_0_x
# 0                      71.4              11.12         9797273.0  Afghanistan
# 1                      36.6              12.33         1747593.0      Albania
# 2                      66.1              11.70        31510100.0      Algeria
# 3                       NaN                NaN           67873.0      Andorra
# 4                      49.1               6.89        21061025.0       Angola
#
#              latitud  longitud
# unnamed_0_x
# 0                NaN       NaN
# 1                NaN       NaN
# 2                NaN       NaN
# 3                NaN       NaN
# 4                NaN       NaN

# %% [markdown]
# 2. Crea una función para añadir una nueva columna llamada 'Continent' al DataFrame para indicar a qué continente pertenece cada país.

# %%
paises_a_continentes = {
    'Afghanistan': 'Asia',
    'Albania': 'Europe',
    'Algeria': 'Africa',
    'Andorra': 'Europe',
    'Angola': 'Africa',
    'Antigua and Barbuda': 'North America',
    'Argentina': 'South America',
    'Armenia': 'Asia',
    'Australia': 'Australia',
    'Austria': 'Europe',
    'Azerbaijan': 'Asia',
    'The Bahamas': 'North America',
    'Bahrain': 'Asia',
    'Bangladesh': 'Asia',
    'Barbados': 'North America',
    'Belarus': 'Europe',
    'Belgium': 'Europe',
    'Belize': 'North America',
    'Benin': 'Africa',
    'Bhutan': 'Asia',
    'Bolivia': 'South America',
    'Bosnia and Herzegovina': 'Europe',
    'Botswana': 'Africa',
    'Brazil': 'South America',
    'Brunei': 'Asia',
    'Bulgaria': 'Europe',
    'Burkina Faso': 'Africa',
    'Burundi': 'Africa',
    'Ivory Coast': 'Africa',
    'Cape Verde': 'Africa',
    'Cambodia': 'Asia',
    'Cameroon': 'Africa',
    'Canada': 'North America',
    'Central African Republic': 'Africa',
    'Chad': 'Africa',
    'Chile': 'South America',
    'China': 'Asia',
    'Colombia': 'South America',
    'Comoros': 'Africa',
    'Republic of the Congo': 'Africa',
    'Costa Rica': 'North America',
    'Croatia': 'Europe',
    'Cuba': 'North America',
    'Cyprus': 'Asia',
    'Czech Republic': 'Europe',
    'Democratic Republic of the Congo': 'Africa',
    'Denmark': 'Europe',
    'Djibouti': 'Africa',
    'Dominica': 'North America',
    'Dominican Republic': 'North America',
    'Ecuador': 'South America',
    'Egypt': 'Africa',
    'El Salvador': 'North America',
    'Equatorial Guinea': 'Africa',
    'Eritrea': 'Africa',
    'Estonia': 'Europe',
    'Eswatini': 'Africa',
    'Ethiopia': 'Africa',
    'Fiji': 'Oceania',
    'Finland': 'Europe',
    'France': 'Europe',
    'Gabon': 'Africa',
    'The Gambia': 'Africa',
    'Georgia': 'Asia',
    'Germany': 'Europe',
    'Ghana': 'Africa',
    'Greece': 'Europe',
    'Grenada': 'North America',
    'Guatemala': 'North America',
    'Guinea': 'Africa',
    'Guinea-Bissau': 'Africa',
    'Guyana': 'South America',
    'Haiti': 'North America',
    'Vatican City': 'Europe',
    'Honduras': 'North America',
    'Hungary': 'Europe',
    'Iceland': 'Europe',
    'India': 'Asia',
    'Indonesia': 'Asia',
    'Iran': 'Asia',
    'Iraq': 'Asia',
    'Republic of Ireland': 'Europe',
    'Israel': 'Asia',
    'Italy': 'Europe',
    'Jamaica': 'North America',
    'Japan': 'Asia',
    'Jordan': 'Asia',
    'Kazakhstan': 'Asia',
    'Kenya': 'Africa',
    'Kiribati': 'Oceania',
    'Kuwait': 'Asia',
    'Kyrgyzstan': 'Asia',
    'Laos': 'Asia',
    'Latvia': 'Europe',
    'Lebanon': 'Asia',
    'Lesotho': 'Africa',
    'Liberia': 'Africa',
    'Libya': 'Africa',
    'Liechtenstein': 'Europe',
    'Lithuania': 'Europe',
    'Luxembourg': 'Europe',
    'Madagascar': 'Africa',
    'Malawi': 'Africa',
    'Malaysia': 'Asia',
    'Maldives': 'Asia',
    'Mali': 'Africa',
    'Malta': 'Europe',
    'Marshall Islands': 'Oceania',
    'Mauritania': 'Africa',
    'Mauritius': 'Africa',
    'Mexico': 'North America',
    'Federated States of Micronesia': 'Oceania',
    'Moldova': 'Europe',
    'Monaco': 'Europe',
    'Mongolia': 'Asia',
    'Montenegro': 'Europe',
    'Morocco': 'Africa',
    'Mozambique': 'Africa',
    'Myanmar': 'Asia',
    'Namibia': 'Africa',
    'Nauru': 'Oceania',
    'Nepal': 'Asia',
    'Netherlands': 'Europe',
    'New Zealand': 'Oceania',
    'Nicaragua': 'North America',
    'Niger': 'Africa',
    'Nigeria': 'Africa',
    'North Korea': 'Asia',
    'North Macedonia': 'Europe',
    'Norway': 'Europe',
    'Oman': 'Asia',
    'Pakistan': 'Asia',
    'Palau': 'Oceania',
    'Palestinian National Authority': 'Asia',
    'Panama': 'North America',
    'Papua New Guinea': 'Oceania',
    'Paraguay': 'South America',
    'Peru': 'South America',
    'Philippines': 'Asia',
    'Poland': 'Europe',
    'Portugal': 'Europe',
    'Qatar': 'Asia',
    'Romania': 'Europe',
    'Russia': 'Europe',
    'Rwanda': 'Africa',
    'Saint Kitts and Nevis': 'North America',
    'Saint Lucia': 'North America',
    'Saint Vincent and the Grenadines': 'North America',
    'Samoa': 'Oceania',
    'San Marino': 'Europe',
    '': '',
    'Saudi Arabia': 'Asia',
    'Senegal': 'Africa',
    'Serbia': 'Europe',
    'Seychelles': 'Africa',
    'Sierra Leone': 'Africa',
    'Singapore': 'Asia',
    'Slovakia': 'Europe',
    'Slovenia': 'Europe',
    'Solomon Islands': 'Oceania',
    'Somalia': 'Africa',
    'South Africa': 'Africa',
    'South Korea': 'Asia',
    'South Sudan': 'Africa',
    'Spain': 'Europe',
    'Sri Lanka': 'Asia',
    'Sudan': 'Africa',
    'Suriname': 'South America',
    'Sweden': 'Europe',
    'Switzerland': 'Europe',
    'Syria': 'Asia',
    'Tajikistan': 'Asia',
    'Tanzania': 'Africa',
    'Thailand': 'Asia',
    'East Timor': 'Asia',
    'Togo': 'Africa',
    'Tonga': 'Oceania',
    'Trinidad and Tobago': 'North America',
    'Tunisia': 'Africa',
    'Turkey': 'Asia',
    'Turkmenistan': 'Asia',
    'Tuvalu': 'Oceania',
    'Uganda': 'Africa',
    'Ukraine': 'Europe',
    'United Arab Emirates': 'Asia',
    'United Kingdom': 'Europe',
    'United States': 'North America',
    'Uruguay': 'South America',
    'Uzbekistan': 'Asia',
    'Vanuatu': 'Oceania',
    'Venezuela': 'South America',
    'Vietnam': 'Asia',
    'Yemen': 'Asia',
    'Zambia': 'Africa',
    'Zimbabwe': 'Africa'
}

# %%
df ['continent'] = df['country'].map(paises_a_continentes)

# %%
df.head(2)
# Out:
#              density(p/km2) abbreviation  agricultural_land  land_area  \
# unnamed_0_x
# 0                      60.0           AF               58.1   652230.0
# 1                     105.0           AL               43.1    28748.0
#
#              armed_forces_size  birth_rate  calling_code capital/major_city  \
# unnamed_0_x
# 0                     323000.0       32.49          93.0              Kabul
# 1                       9000.0       11.78         355.0             Tirana
#
#              co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# unnamed_0_x
# 0                   8672.0  149.90         2.3           AFN            4.47
# 1                   4536.0  119.05         1.4           ALL            1.62
#
#              forested_area  gasoline_price  unnamed_0_y           gdp  \
# unnamed_0_x
# 0                      2.1            0.70            0  1.910135e+10
# 1                     28.1            1.36            1  1.527808e+10
#
#              gross_primary_education_enrollment  \
# unnamed_0_x
# 0                                         104.0
# 1                                         107.0
#
#              gross_tertiary_education_enrollment  infant_mortality  \
# unnamed_0_x
# 0                                            9.7              47.9
# 1                                           55.0               7.8
#
#             largest_city  life_expectancy  maternal_mortality_ratio  \
# unnamed_0_x
# 0                  Kabul             64.5                     638.0
# 1                 Tirana             78.5                      15.0
#
#              minimum_wage official_language  out_of_pocket_health_expenditure  \
# unnamed_0_x
# 0                    0.43            Pashto                              78.4
# 1                    1.12          Albanian                              56.9
#
#              physicians_per_thousand  population  \
# unnamed_0_x
# 0                               0.28  38041754.0
# 1                               1.20   2854191.0
#
#              population_labor_force_participation  tax_revenue  \
# unnamed_0_x
# 0                                            48.9          9.3
# 1                                            55.7         18.6
#
#              total_tax_rate  unemployment_rate  urban_population      country  \
# unnamed_0_x
# 0                      71.4              11.12         9797273.0  Afghanistan
# 1                      36.6              12.33         1747593.0      Albania
#
#              latitud  longitud continent
# unnamed_0_x
# 0                NaN       NaN      Asia
# 1                NaN       NaN    Europe

# %% [markdown]
# 3. Guarda el DataFrame después de los cambios creados después de los dos ejercicios anteriores para usarlo en el pairprogramming de mañana.

# %%
df.to_csv ('world_data_total_2.csv')

# %% [markdown]
# ## Ejercicios groupby

# %% [markdown]
# 1. ¿Cuál es la densidad de población promedio por continente?

# %%
df.groupby ('continent')['density(p/km2)'].mean().reset_index()
# Out:
#        continent  density(p/km2)
# 0         Africa      105.094340
# 1           Asia      446.291667
# 2      Australia        3.000000
# 3         Europe      798.090909
# 4  North America      188.826087
# 5        Oceania      199.000000
# 6  South America       25.000000

# %% [markdown]
# 2. ¿Cuál es la esperanza de vida promedio por idioma oficial? Agrupa los países por idioma oficial y calcula la esperanza de vida promedio.

# %%
df.groupby (['country','official_language'])['life_expectancy'].mean().reset_index()
# Out:
#          country official_language  life_expectancy
# 0    Afghanistan            Pashto             64.5
# 1        Albania          Albanian             78.5
# 2        Algeria            Arabic             76.7
# 3        Andorra           Catalan              NaN
# 4         Angola        Portuguese             60.8
# ..           ...               ...              ...
# 185    Venezuela           Spanish             72.1
# 186      Vietnam        Vietnamese             75.3
# 187        Yemen            Arabic             66.1
# 188       Zambia           English             63.5
# 189     Zimbabwe             Shona             61.2
#
# [190 rows x 3 columns]

# %% [markdown]
# 3. ¿Cuál es la tasa de mortalidad infantil promedio por moneda?

# %%
df.groupby ('currency-code')['infant_mortality'].mean().reset_index()
# Out:
#     currency-code  infant_mortality
# 0             AED          6.500000
# 1             AFN         47.900000
# 2             ALL          7.800000
# 3             AMD         11.000000
# 4             AOA         51.600000
# ..            ...               ...
# 128           XCD         15.183333
# 129           XOF         51.512500
# 130           YER         42.900000
# 131           ZAR         28.500000
# 132           ZMW         40.400000
#
# [133 rows x 2 columns]

# %% [markdown]
# 4. ¿Cuál es el salario mínimo por continente?

# %%
df.groupby ('continent')['minimum_wage'].mean().reset_index()
# Out:
#        continent  minimum_wage
# 0         Africa      0.530000
# 1           Asia      1.474324
# 2      Australia     13.590000
# 3         Europe      4.784688
# 4  North America      2.266190
# 5        Oceania      2.708750
# 6  South America      1.582727

# %% [markdown]
# 5. ¿Cuál es la tasa de impuestos total máxima por densidad de población por continente? Para solucionar este ejercicio puedes:
#
#     Primero, necesitas calcular la tasa de impuestos total para cada continente. La tasa de impuestos total se encuentra en la columna columna "total_tax_rate".
#
#     Luego, calcula la densidad de población para cada continente. La densidad de población se encuentra en la columna "density".
#
#     Ahora, divide la tasa de impuestos total entre la densidad de población para obtener la tasa de impuestos total por persona por kilómetro cuadrado.
#
#     Encuentra el país que tiene el valor más alto en esta nueva columna calculada.

# %%
df.groupby ('continent')["total_tax_rate"].sum().reset_index()
# Out:
#        continent  total_tax_rate
# 0         Africa          2436.3
# 1           Asia          1441.6
# 2      Australia            47.4
# 3         Europe          1545.9
# 4  North America           895.4
# 5        Oceania           426.8
# 6  South America           640.1

# %%
df.groupby ('continent')['density(p/km2)'].sum().reset_index()
# Out:
#        continent  density(p/km2)
# 0         Africa          5570.0
# 1           Asia         21422.0
# 2      Australia             3.0
# 3         Europe         35116.0
# 4  North America          4343.0
# 5        Oceania          2587.0
# 6  South America           300.0

# %% [markdown]
# 6. ¿Cuál es el porcentaje de población urbana promedio por continente?

# %% [markdown]
# 7. ¿Cuál es la diferencia entre el PIB promedio y el gasto en salud de bolsillo promedio por idioma oficial? Para contestar esta pregunta dabes seguir los siguientes pasos:
#
#     Agrupa el DataFrame por idioma oficial y calcula la media del Gasto de Bolsillo en salud (out_of_pocket_health_expenditure) y del GPD.
#
#     Calcula la diferencia entre el PIB promedio y el gasto en salud de bolsillo promedio

# %% [markdown]
# 8. ¿Cuál es la tasa de maternidad promedio por tasa de impuestos total? Para resolver el ejercicio deberás:
#
#     Primero, calcula la tasa de maternidad promedio para cada continente. Puedes usar la columna "maternal_mortality_ratio" que representa la tasa de mortalidad materna.
#
#     Calcula la tasa de impuestos total promedio para cada continente. Puedes usar la columna "total_tax_rate" que representa la tasa de impuestos total en cada continente.
#
#     Luego, divide la tasa de maternidad promedio por la tasa de impuestos total promedio para obtener la relación entre ambas tasas.
#
#     Encuentra el país con la tasa de maternidad más alta por punto porcentual de tasa de impuestos total.

# %% [markdown]
# 9. Ejercicios bonus groupby:
#
#     ¿Cuál es la tasa de natalidad máxima por área forestal por continente? Encuentra el país con la tasa de natalidad más alta por cada punto porcentual de área forestal.
#
#     ¿Cuál es la diferencia entre la tasa de impuestos total y la tasa de desempleo promedio por continente?
